# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: requests>=2.31 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\liuda\onedrive\documents\github\ml-market-prediction\sklearn-env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import yfinance as yf
sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period = "max")
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-09-17 00:00:00-04:00  5655.509766  5670.810059  5614.049805  5634.580078
# 2024-09-18 00:00:00-04:00  5641.680176  5689.750000  5615.080078  5618.259766
# 2024-09-19 00:00:00-04:00  5702.629883  5733.569824  5686.419922  5713.640137
# 2024-09-20 00:00:00-04:00  5709.640137  5715.140137  5674.490234  5702.549805
# 2024-09-23 00:00:00-04:00  5711.899902  5725.359863  5704.220215  5718.569824
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2024-09-17 00:00:00-04:00  3443600000        0.0           0.0
# 2024-09-18 00:00:00-04:00  3691390000        0.0           0.0
# 2024-09-19 00:00:00-04:00  4024530000        0.0           0.0
# 2024-09-20 00:00:00-04:00  7867260000        0.0           0.0
# 2024-09-23 00:00:00-04:00  3529550000        0.0           0.0
#
# [24298 rows x 7 columns]

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-09-10 00:00:00-04:00', '2024-09-11 00:00:00-04:00',
#                '2024-09-12 00:00:00-04:00', '2024-09-13 00:00:00-04:00',
#                '2024-09-16 00:00:00-04:00', '2024-09-17 00:00:00-04:00',
#                '2024-09-18 00:00:00-04:00', '2024-09-19 00:00:00-04:00',
#                '2024-09-20 00:00:00-04:00', '2024-09-23 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24298, freq=None)

# %%
sp500.plot.line(y = "Close", use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500.loc["1990-01-01":].copy()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-09-17 00:00:00-04:00  5655.509766  5670.810059  5614.049805  5634.580078
# 2024-09-18 00:00:00-04:00  5641.680176  5689.750000  5615.080078  5618.259766
# 2024-09-19 00:00:00-04:00  5702.629883  5733.569824  5686.419922  5713.640137
# 2024-09-20 00:00:00-04:00  5709.640137  5715.140137  5674.490234  5702.549805
# 2024-09-23 00:00:00-04:00  5711.899902  5725.359863  5704.220215  5718.569824
#
#                                Volume     Tomorrow  Target
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0
# ...                               ...          ...     ...
# 2024-09-17 00:00:00-04:00  3443600000  5618.259766       0
# 2024-09-18 00:00:00-04:00  3691390000  5713.640137       1
# 2024-09-19 00:00:00-04:00  4024530000  5702.549805       0
# 2024-09-20 00:00:00-04:00  7867260000  5718.569824       1
# 2024-09-23 00:00:00-04:00  3529550000          NaN       0
#
# [8748 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, min_samples_split = 100, random_state = 1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]
predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# np.float64(1.0)

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)

    return combined

# %%
import concurrent.futures

def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = []
        for i in range(start, data.shape[0], step):
            train = data.iloc[0:i]
            test = data.iloc[i:(i+step)]
            futures.append(executor.submit(predict, train, test, predictors, model))
        
        for future in concurrent.futures.as_completed(futures):
            all_predictions.append(future.result())
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 predictions = backtest(sp500, model, predictors)
#
# NameError: name 'backtest' is not defined

# %%
predictions["Predictions"].value_counts()

# %%
precision_score(predictions["Target"], predictions["Predictions"])

# %%
predictions["Target"].value_counts() / predictions.shape[0]

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages ["Close"]
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()
sp500

# %%
model = RandomForestClassifier(n_estimators = 200, min_samples_split = 50, random_state = 1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)

    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
